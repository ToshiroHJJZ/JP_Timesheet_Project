# %% [markdown]
# # Programming Project 1 analysis using EDA tools
# - Name: Jonathan Penaloza
# - Date: 10/3/2023
# - Version: 1

# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Load the dataset and save it to a dataframe named 'df'
# ![image.png](attachment:image.png)

# %%
df =pd.read_csv('JP_Timesheet_Project.csv')

# %%
print(df.head())
# Out:
#   initials      date    course_id  time(m)  \
# 0       JP  9/5/2023     DS160-01       80
# 1       JP  9/5/2023  FILM-270-01       70
# 2       JP  9/5/2023  MATH-205-03      140
# 3       JP  9/5/2023  FILM-270-01      120
# 4       JP  9/6/2023  MATH-205-03      120
#
#                                  summary
# 0  Worked with Excell doing data anlysis
# 1            Talk about a movie + lesson
# 2                                Lecture
# 3                              Homework.
# 4                                Lecture

# %% [markdown]
# ### Investigate your dataset

# %%
df.head(10)
# Out:
#   initials      date    course_id  time(m)  \
# 0       JP  9/5/2023     DS160-01       80
# 1       JP  9/5/2023  FILM-270-01       70
# 2       JP  9/5/2023  MATH-205-03      140
# 3       JP  9/5/2023  FILM-270-01      120
# 4       JP  9/6/2023  MATH-205-03      120
# 5       JP  9/6/2023    CS-215-01       50
# 6       JP  9/6/2023     MUSI-111       60
# 7       JP  9/6/2023  MATH-430-01       75
# 8       JP  9/7/2023     DS160-01       80
# 9       JP  9/7/2023    CS-215-01      120
#
#                                  summary
# 0  Worked with Excell doing data anlysis
# 1            Talk about a movie + lesson
# 2                                Lecture
# 3                              Homework.
# 4                                Lecture
# 5                                Lecture
# 6                           Piano Lesson
# 7                                 Lesson
# 8                                Lecture
# 9                                    Lab

# %%
df.tail(10)
# Out:
#    initials       date    course_id  time(m)            summary
# 42       JP  9/26/2023  MATH-205-03      140            Lecture
# 43       JP  9/27/2023    CS-215-01       50            Lecture
# 44       JP  9/27/2023     MUSI-111       60       Piano Lesson
# 45       JP  9/27/2023  MATH-430-01       75  Homework practice
# 46       JP  9/28/2023     DS160-01       80            lecture
# 47       JP  9/28/2023    CS-215-01      120                Lab
# 48       JP  9/28/2023    CS-215-01      480           Homework
# 49       JP  10/2/2023    CS-215-01       50            Lecture
# 50       JP  10/2/2023  MATH-430-01       80            Lecture
# 51       JP  10/2/2023  MUSE-133-01      150     Choir practice

# %%
df.sample(10)
# Out:
#    initials       date    course_id  time(m)                     summary
# 38       JP  9/25/2023  MATH-430-01       80                     Lecture
# 50       JP  10/2/2023  MATH-430-01       80                     Lecture
# 46       JP  9/28/2023     DS160-01       80                     lecture
# 44       JP  9/27/2023     MUSI-111       60                Piano Lesson
# 10       JP   9/7/2023  MATH-205-03      140              Lecture + Quiz
# 42       JP  9/26/2023  MATH-205-03      140                     Lecture
# 18       JP  9/12/2023  MATH-205-03      120                     Lecture
# 31       JP  9/20/2023     MUSI-111       60                Piano Lesson
# 36       JP  9/25/2023    CS-215-01       40  Homework and JAVA learning
# 45       JP  9/27/2023  MATH-430-01       75           Homework practice

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   initials   52 non-null     object
#  1   date       52 non-null     object
#  2   course_id  52 non-null     object
#  3   time(m)    52 non-null     int64
#  4   summary    52 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations
# ![image.png](attachment:image.png)

# %%
sns.set(rc={'figure.figsize':(10,5)}, font_scale=1, style='whitegrid')
sns.boxplot(x='course_id', y ='time(m)', data = df)
# Out:
# <AxesSubplot:xlabel='course_id', ylabel='time(m)'>

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days
# ![image.png](attachment:image.png)

# %%
df['date'] = pd.to_datetime(df['date'])
df['day_name'] = df['date'].dt.day_name()
df['day'] = range(1, len(df) +1)
df.head()
# Out:
#   initials       date    course_id  time(m)  \
# 0       JP 2023-09-05     DS160-01       80
# 1       JP 2023-09-05  FILM-270-01       70
# 2       JP 2023-09-05  MATH-205-03      140
# 3       JP 2023-09-05  FILM-270-01      120
# 4       JP 2023-09-06  MATH-205-03      120
#
#                                  summary   day_name  day
# 0  Worked with Excell doing data anlysis    Tuesday    1
# 1            Talk about a movie + lesson    Tuesday    2
# 2                                Lecture    Tuesday    3
# 3                              Homework.    Tuesday    4
# 4                                Lecture  Wednesday    5

# %% [markdown]
# ### Data Visualization:
# 1. Create a histogram or bar chart to visually represent the distribution of time spent.
# 2. Create a  bar chart to visually represent the distribution of time spent on different courses and comment on the course you spent most and least time
# ![image-3.png](attachment:image-3.png)

# %%
plt.hist(df['time(m)'])
# Out:
# (array([34.,  8.,  9.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 40.,  84., 128., 172., 216., 260., 304., 348., 392., 436., 480.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see how often you engaged in each.

# %%
sns.countplot (x = 'course_id', data = df)
# Out:
# <AxesSubplot:xlabel='course_id', ylabel='count'>

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
sns.lineplot(x='day', 
             y='time(m)',
             data = df,
            hue = 'course_id',
            ci = False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='time(m)'>

# %% [markdown]
# ### Course Analysis:
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
a = df.query('course_id=="DS160-01"')['time(m)'].sum()
print(f"The total time spent on DS160-01 is: {a} minutes.")
# Out:
# The total time spent on DS160-01 is: 560 minutes.

# %%
b = df.query('course_id=="FILM-270-01"')['time(m)'].sum()
print(f"The total time spent on FILM-270-01 is: {b} minutes.")
# Out:
# The total time spent on FILM-270-01 is: 640 minutes.

# %%
c = df.query('course_id=="MATH-205-03"')['time(m)'].sum()
print(f"The total time spent on MATH-205-03 is: {c} minutes.")
# Out:
# The total time spent on FILM-270-01 is: 1015 minutes.

# %%
d = df.query('course_id=="CS-215-01"')['time(m)'].sum()
print(f"The total time spent on CS-215-01 is: {d} minutes.")
# Out:
# The total time spent on FILM-270-01 is: 1320 minutes.

# %%
e = df.query('course_id=="MUSI-111"')['time(m)'].sum()
print(f"The total time spent on MUSI-111 is: {e} minutes.")
# Out:
# The total time spent on MUSI-111 is: 240 minutes.

# %%
f = df.query('course_id=="MUSE-133-01"')['time(m)'].sum()
print(f"The total time spent on MUSE-133-01 is: {f} minutes.")
# Out:
# The total time spent on MUSE-133-01 is: 600 minutes.

# %%
g = df.query('course_id=="MATH-430-01"')['time(m)'].sum()
print(f"The total time spent on MATH-430-01 is: {g} minutes.")
# Out:
# The total time spent on MATH-430-01 is: 600 minutes.

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less.
# ![image.png](attachment:image.png)

# %%
heat_map=df[['day','time(m)']].corr()
cols=['day','time(m)']
print(heat_map)

sns.heatmap(heat_map, xticklabels=cols, yticklabels=cols, annot=True)
# Out:
#               day   time(m)
# day      1.000000  0.170809
# time(m)  0.170809  1.000000
# <AxesSubplot:>

# %% [markdown]
# Reflection:
#     I learned in this project that I can represent data in multiple ways, one of which I found interesting was the time I spend on each of my classes. Through boxplots, histograms, lineplots, and heat maps, I was able to see how long I spent each day studying, how long I studied for each of my classes, and which classes seemed more of a priority to me. In more recent days, I have noticed that my CS class has gotten more relevant, to be more specific, last Thursday (where, in fact, I was completing an assignment and it took me 8 hours).  Analysing my study time through various visualisations has provided valuable insights into my academic priorities. Notably, I have observed a significant increase in the relevance of my CS class, as evidenced by the extensive 8-hour assignment I completed last Thursday. This newfound importance has prompted me to allocate more time and effort towards mastering the subject.
